# %%
import gensim.downloader as api

# %%
wv = api.load("word2vec-google-news-300")
# Out:
# [--------------------------------------------------] 1.4% 23.4/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [==------------------------------------------------] 5.2% 87.0/1662.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [===-----------------------------------------------] 6.5% 107.8/1662.8MB downloaded
# IOPub message rate exceeded.
# ...

# %%
wv.similarity(w1="great", w2="good")
# Out:
# 0.729151

# %%
wv.similarity(w1="great", w2="well")
# Out:
# 0.40982714

# %%
wv.similarity(w1="profit", w2="loss")
# Out:
# 0.34199455

# %%
wv.similarity(w1="profit", w2="margin")
# Out:
# 0.25816035

# %%
wv.most_similar("good")
# Out:
# [('great', 0.7291508913040161),
#  ('bad', 0.7190051078796387),
#  ('terrific', 0.6889115571975708),
#  ('decent', 0.6837348937988281),
#  ('nice', 0.6836092472076416),
#  ('excellent', 0.644292950630188),
#  ('fantastic', 0.6407778263092041),
#  ('better', 0.6120728850364685),
#  ('solid', 0.5806035399436951),
#  ('lousy', 0.576420247554779)]

# %%
wv.most_similar("cat")
# Out:
# [('cats', 0.8099378347396851),
#  ('dog', 0.760945737361908),
#  ('kitten', 0.7464984655380249),
#  ('feline', 0.7326233983039856),
#  ('beagle', 0.7150583267211914),
#  ('puppy', 0.7075453996658325),
#  ('pup', 0.6934291124343872),
#  ('pet', 0.6891531348228455),
#  ('felines', 0.6755931377410889),
#  ('chihuahua', 0.6709762215614319)]

# %%
King - woman + man = Queen

France - Paris + Berline = Germany

# %%
wv.most_similar(positive=["france", "berlin"], negative=["paris"])
# Out:
# [('germany', 0.5094343423843384),
#  ('european', 0.4865044951438904),
#  ('german', 0.4714890122413635),
#  ('austria', 0.46964019536972046),
#  ('swedish', 0.4645182490348816),
#  ('Wissenschaft', 0.4532880485057831),
#  ('denmark', 0.4477355182170868),
#  ('München', 0.4438531994819641),
#  ('europe', 0.4420619606971741),
#  ('belgium', 0.43769749999046326)]

# %%
wv.most_similar(positive=["king", "woman"], negative=["man"])
# Out:
# [('queen', 0.7118192911148071),
#  ('monarch', 0.6189674735069275),
#  ('princess', 0.5902431011199951),
#  ('crown_prince', 0.5499460697174072),
#  ('prince', 0.5377321243286133),
#  ('kings', 0.5236844420433044),
#  ('Queen_Consort', 0.5235945582389832),
#  ('queens', 0.5181134343147278),
#  ('sultan', 0.5098593235015869),
#  ('monarchy', 0.5087411403656006)]

# %%
wv.doesnt_match(["Tesla", "Facebook", "Meta", "Google", "cat"])
# Out:
# 'cat'

# %%
glv = api.load("glove-twitter-25")
# Out:
# [===========---------------------------------------] 22.4% 23.4/104.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [===========================-----------------------] 54.3% 56.9/104.8MB downloaded
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [============================================------] 89.2% 93.4/104.8MB downloaded
# IOPub message rate exceeded.
# ...

# %%
glv.most_similar("xiaomi")
# Out:
# [('laferrari', 0.9122025966644287),
#  ('vellfire', 0.900170624256134),
#  ('rolls-royce', 0.8984930515289307),
#  ('docusign', 0.8817274570465088),
#  ('primesense', 0.8805124759674072),
#  ('rezound', 0.873680591583252),
#  ('visconti', 0.8735998272895813),
#  ('qualcomm', 0.8723087310791016),
#  ('windstar', 0.8716853857040405),
#  ('padfone', 0.8665919303894043)]

# %%
glv.doesnt_match("good bad feel cat".split())
# Out:
# 'cat'

# %% [markdown]
# # 9 Spacy Language Processing Pipeline.ipynb

# %%
import spacy

# %%
nlp = spacy.blank("en")

doc = nlp("Captain America ate 100$ of samosa. The he said I can do this all day.")

for token in doc:
  print(token)
# Out:
# Captain
# America
# ate
# 100
# $
# of
# samosa
# .
# The
# he
# said
# I
# can
# do
# this
# all
# day
# .

# %%
nlp.pipe_names
# Out:
# []

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 94.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load("en_core_web_sm")
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7ea76bf44770>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7ea76bb76270>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7ea76bc292a0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7ea76b99c7d0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7ea76b998310>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7ea76bc29380>)]

# %%
doc = nlp("Captain America ate 100$ of samosa. The he said I can do this all day.")

for token in doc:
  print(f'''{token.text:<10} |  {token.pos_:<10} |  {token.lemma_:<10}''')
# Out:
# Captain    |  PROPN      |  Captain
# America    |  PROPN      |  America
# ate        |  VERB       |  eat
# 100        |  NUM        |  100
# $          |  NUM        |  $
# of         |  ADP        |  of
# samosa     |  PROPN      |  samosa
# .          |  PUNCT      |  .
# The        |  DET        |  the
# he         |  PRON       |  he
# said       |  VERB       |  say
# I          |  PRON       |  I
# can        |  AUX        |  can
# do         |  VERB       |  do
# this       |  PRON       |  this
# all        |  DET        |  all
# day        |  NOUN       |  day
# .          |  PUNCT      |  .

# %%
# NER
doc = nlp("Tesla INc is going to acquire Twitter for $45 billion.")
for ent in doc.ents:
  print(ent.text, "|",  ent.label_, "|", spacy.explain(ent.label_))
# Out:
# Tesla INc | ORG | Companies, agencies, institutions, etc.
# Twitter | PERSON | People, including fictional
# $45 billion | MONEY | Monetary values, including unit

# %%
from spacy import displacy
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla INc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to acquire
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
# ...

# %%
text = "Bloomberg founded data company called Bloomberg"
doc = nlp(text)

for ent in doc.ents:
  print(ent.text, ent.label_)
# Out:
# Bloomberg ORG
# Bloomberg ORG

# %% [markdown]
# First Bloomberg should be a person

# %%
nlp = spacy.blank("en")

doc = nlp("Captain America ate 100$ of samosa. The he said I can do this all day.")

for ent in doc.ents:
  print(ent.text)

# %%
source_nlp = spacy.load("en_core_web_sm")

nlp = spacy.blank("en")
nlp.add_pipe("ner", source=source_nlp)

doc = nlp("Captain America ate 100$ of samosa. The he said I can do this all day.")

nlp.pipe_names
# Out:
# ['ner']
